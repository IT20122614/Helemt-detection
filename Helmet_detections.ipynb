# %% [markdown]
# <a href="https://colab.research.google.com/github/IT20122614/Helemt-detection/blob/main/Helmet_detections.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <div align="center">
#
#   <a href="https://ultralytics.com/yolov5" target="_blank">
#     <img width="1024", src="https://raw.githubusercontent.com/ultralytics/assets/main/yolov5/v70/splash.png"></a>
#
#
# <br>
#   <a href="https://bit.ly/yolov5-paperspace-notebook"><img src="https://assets.paperspace.io/img/gradient-badge.svg" alt="Run on Gradient"></a>
#   <a href="https://colab.research.google.com/github/ultralytics/yolov5/blob/master/tutorial.ipynb"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"></a>
#   <a href="https://www.kaggle.com/ultralytics/yolov5"><img src="https://kaggle.com/static/images/open-in-kaggle.svg" alt="Open In Kaggle"></a>
# <br>
#
# This <a href="https://github.com/ultralytics/yolov5">YOLOv5</a> 🚀 notebook by <a href="https://ultralytics.com">Ultralytics</a> presents simple train, validate and predict examples to help start your AI adventure.<br>We hope that the resources in this notebook will help you get the most out of YOLOv5. Please browse the YOLOv5 <a href="https://docs.ultralytics.com/yolov5">Docs</a> for details, raise an issue on <a href="https://github.com/ultralytics/yolov5">GitHub</a> for support, and join our <a href="https://discord.gg/n6cFeSPZdD">Discord</a> community for questions and discussions!
#
# </div>

# %% [markdown]
# # Setup
#
# Clone GitHub [repository](https://github.com/ultralytics/yolov5), install [dependencies](https://github.com/ultralytics/yolov5/blob/master/requirements.txt) and check PyTorch and GPU.

# %%
# !git clone https://github.com/ultralytics/yolov5  # clone
# %cd yolov5
# %pip install -qr requirements.txt  # install

import torch
import utils
display = utils.notebook_init()  # checks
# Out:
# YOLOv5 🚀 v7.0-169-geef637c Python-3.10.11 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 23.3/78.2 GB disk)

# %%
# !unzip -q ../train_data.zip -d ../

# %% [markdown]
# # 1. Detect
#
# `detect.py` runs YOLOv5 inference on a variety of sources, downloading models automatically from the [latest YOLOv5 release](https://github.com/ultralytics/yolov5/releases), and saving results to `runs/detect`. Example inference sources are:
#
# ```shell
# python detect.py --source 0  # webcam
#                           img.jpg  # image
#                           vid.mp4  # video
#                           screen  # screenshot
#                           path/  # directory
#                          'path/*.jpg'  # glob
#                          'https://youtu.be/Zgi9g1ksQHc'  # YouTube
#                          'rtsp://example.com/media.mp4'  # RTSP, RTMP, HTTP stream
# ```

# %%
# !python detect.py --weights runs/train/exp3/weights/best.pt --img 640 --conf 0.25 --source ../signs.mp4
# display.Image(filename='runs/detect/exp/zidane.jpg', width=600)
# Out:
# detect: weights=['runs/train/exp3/weights/best.pt'], source=../signs.mp4, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# requirements: /usr/local/lib/python3.10/dist-packages/requirements.txt not found, check failed.
# YOLOv5 🚀 v7.0-168-gec2b853 Python-3.10.11 torch-2.0.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
#
# Fusing layers...
# Model summary: 157 layers, 7012822 parameters, 0 gradients, 15.8 GFLOPs
# video 1/1 (1/194) /content/signs.mp4: 384x640 3 Helmets, 43.4ms
# video 1/1 (2/194) /content/signs.mp4: 384x640 2 Helmets, 7.9ms
# video 1/1 (3/194) /content/signs.mp4: 384x640 3 Helmets, 7.9ms
# video 1/1 (4/194) /content/signs.mp4: 384x640 2 Helmets, 7.9ms
# video 1/1 (5/194) /content/signs.mp4: 384x640 2 Helmets, 7.9ms
# video 1/1 (6/194) /content/signs.mp4: 384x640 1 Helmet, 8.0ms
# video 1/1 (7/194) /content/signs.mp4: 384x640 2 Helmets, 7.8ms
# video 1/1 (8/194) /content/signs.mp4: 384x640 2 Helmets, 7.9ms
# video 1/1 (9/194) /content/signs.mp4: 384x640 3 Helmets, 7.9ms
# video 1/1 (10/194) /content/signs.mp4: 384x640 1 Helmet, 7.9ms
# video 1/1 (11/194) /content/signs.mp4: 384x640 1 Helmet, 7.9ms
# video 1/1 (12/194) /content/signs.mp4: 384x640 (no detections), 7.9ms
# video 1/1 (13/194) /content/signs.mp4: 384x640 2 Helmets, 7.9ms
# video 1/1 (14/194) /content/signs.mp4: 384x640 1 Helmet, 7.9ms
# video 1/1 (15/194) /content/signs.mp4: 384x640 1 Helmet, 7.9ms
# video 1/1 (16/194) /content/signs.mp4: 384x640 1 Helmet, 7.9ms
# video 1/1 (17/194) /content/signs.mp4: 384x640 2 Helmets, 7.9ms
# video 1/1 (18/194) /content/signs.mp4: 384x640 1 Helmet, 7.8ms
# video 1/1 (19/194) /content/signs.mp4: 384x640 2 Helmets, 7.4ms
# video 1/1 (20/194) /content/signs.mp4: 384x640 2 Helmets, 7.4ms
# video 1/1 (21/194) /content/signs.mp4: 384x640 2 Helmets, 7.4ms
# video 1/1 (22/194) /content/signs.mp4: 384x640 3 Helmets, 7.4ms
# video 1/1 (23/194) /content/signs.mp4: 384x640 1 Helmet, 7.4ms
# video 1/1 (24/194) /content/signs.mp4: 384x640 2 Helmets, 7.4ms
# video 1/1 (25/194) /content/signs.mp4: 384x640 2 Helmets, 7.4ms
# video 1/1 (26/194) /content/signs.mp4: 384x640 1 Helmet, 7.4ms
# video 1/1 (27/194) /content/signs.mp4: 384x640 2 Helmets, 7.4ms
# video 1/1 (28/194) /content/signs.mp4: 384x640 2 Helmets, 7.4ms
# video 1/1 (29/194) /content/signs.mp4: 384x640 3 Helmets, 8.7ms
# video 1/1 (30/194) /content/signs.mp4: 384x640 2 Helmets, 7.1ms
# video 1/1 (31/194) /content/signs.mp4: 384x640 2 Helmets, 7.2ms
# video 1/1 (32/194) /content/signs.mp4: 384x640 2 Helmets, 7.2ms
# video 1/1 (33/194) /content/signs.mp4: 384x640 2 Helmets, 7.1ms
# video 1/1 (34/194) /content/signs.mp4: 384x640 (no detections), 7.1ms
# video 1/1 (35/194) /content/signs.mp4: 384x640 (no detections), 7.1ms
# video 1/1 (36/194) /content/signs.mp4: 384x640 2 Helmets, 7.1ms
# video 1/1 (37/194) /content/signs.mp4: 384x640 2 Helmets, 7.1ms
# video 1/1 (38/194) /content/signs.mp4: 384x640 2 Helmets, 7.1ms
# video 1/1 (39/194) /content/signs.mp4: 384x640 1 Helmet, 7.1ms
# video 1/1 (40/194) /content/signs.mp4: 384x640 2 Helmets, 7.1ms
# video 1/1 (41/194) /content/signs.mp4: 384x640 1 Helmet, 7.1ms
# video 1/1 (42/194) /content/signs.mp4: 384x640 1 Helmet, 7.1ms
# video 1/1 (43/194) /content/signs.mp4: 384x640 1 Helmet, 7.1ms
# video 1/1 (44/194) /content/signs.mp4: 384x640 1 Helmet, 7.1ms
# video 1/1 (45/194) /content/signs.mp4: 384x640 2 Helmets, 7.2ms
# video 1/1 (46/194) /content/signs.mp4: 384x640 1 Helmet, 7.1ms
# video 1/1 (47/194) /content/signs.mp4: 384x640 1 Helmet, 7.1ms
# video 1/1 (48/194) /content/signs.mp4: 384x640 1 Helmet, 7.1ms
# video 1/1 (49/194) /content/signs.mp4: 384x640 1 Helmet, 7.1ms
# video 1/1 (50/194) /content/signs.mp4: 384x640 1 Helmet, 7.0ms
# video 1/1 (51/194) /content/signs.mp4: 384x640 1 Helmet, 7.0ms
# video 1/1 (52/194) /content/signs.mp4: 384x640 1 Helmet, 7.0ms
# video 1/1 (53/194) /content/signs.mp4: 384x640 2 Helmets, 7.0ms
# video 1/1 (54/194) /content/signs.mp4: 384x640 2 Helmets, 7.0ms
# video 1/1 (55/194) /content/signs.mp4: 384x640 1 Helmet, 7.0ms
# video 1/1 (56/194) /content/signs.mp4: 384x640 1 Helmet, 7.0ms
# video 1/1 (57/194) /content/signs.mp4: 384x640 2 Helmets, 7.0ms
# video 1/1 (58/194) /content/signs.mp4: 384x640 1 Helmet, 8.8ms
# video 1/1 (59/194) /content/signs.mp4: 384x640 3 Helmets, 7.0ms
# video 1/1 (60/194) /content/signs.mp4: 384x640 3 Helmets, 7.0ms
# video 1/1 (61/194) /content/signs.mp4: 384x640 3 Helmets, 7.0ms
# video 1/1 (62/194) /content/signs.mp4: 384x640 2 Helmets, 7.0ms
# video 1/1 (63/194) /content/signs.mp4: 384x640 2 Helmets, 7.0ms
# video 1/1 (64/194) /content/signs.mp4: 384x640 2 Helmets, 7.0ms
# video 1/1 (65/194) /content/signs.mp4: 384x640 (no detections), 7.0ms
# video 1/1 (66/194) /content/signs.mp4: 384x640 (no detections), 7.0ms
# video 1/1 (67/194) /content/signs.mp4: 384x640 1 Helmet, 7.0ms
# video 1/1 (68/194) /content/signs.mp4: 384x640 1 Helmet, 7.0ms
# video 1/1 (69/194) /content/signs.mp4: 384x640 1 Helmet, 7.0ms
# video 1/1 (70/194) /content/signs.mp4: 384x640 1 Helmet, 7.0ms
# video 1/1 (71/194) /content/signs.mp4: 384x640 1 Helmet, 7.0ms
# video 1/1 (72/194) /content/signs.mp4: 384x640 (no detections), 7.0ms
# video 1/1 (73/194) /content/signs.mp4: 384x640 (no detections), 7.0ms
# video 1/1 (74/194) /content/signs.mp4: 384x640 2 Helmets, 7.0ms
# video 1/1 (75/194) /content/signs.mp4: 384x640 1 Helmet, 7.0ms
# video 1/1 (76/194) /content/signs.mp4: 384x640 2 Helmets, 7.0ms
# video 1/1 (77/194) /content/signs.mp4: 384x640 2 Helmets, 7.0ms
# video 1/1 (78/194) /content/signs.mp4: 384x640 (no detections), 7.1ms
# video 1/1 (79/194) /content/signs.mp4: 384x640 2 Helmets, 7.0ms
# video 1/1 (80/194) /content/signs.mp4: 384x640 (no detections), 7.0ms
# video 1/1 (81/194) /content/signs.mp4: 384x640 1 Helmet, 8.0ms
# video 1/1 (82/194) /content/signs.mp4: 384x640 (no detections), 7.0ms
# video 1/1 (83/194) /content/signs.mp4: 384x640 (no detections), 9.6ms
# video 1/1 (84/194) /content/signs.mp4: 384x640 (no detections), 7.0ms
# video 1/1 (85/194) /content/signs.mp4: 384x640 1 Helmet, 7.0ms
# video 1/1 (86/194) /content/signs.mp4: 384x640 (no detections), 8.3ms
# video 1/1 (87/194) /content/signs.mp4: 384x640 1 Helmet, 7.0ms
# video 1/1 (88/194) /content/signs.mp4: 384x640 (no detections), 7.0ms
# video 1/1 (89/194) /content/signs.mp4: 384x640 1 Helmet, 7.0ms
# video 1/1 (90/194) /content/signs.mp4: 384x640 2 Helmets, 7.0ms
# video 1/1 (91/194) /content/signs.mp4: 384x640 (no detections), 7.0ms
# video 1/1 (92/194) /content/signs.mp4: 384x640 (no detections), 7.0ms
# video 1/1 (93/194) /content/signs.mp4: 384x640 (no detections), 7.0ms
# video 1/1 (94/194) /content/signs.mp4: 384x640 (no detections), 7.0ms
# video 1/1 (95/194) /content/signs.mp4: 384x640 1 Helmet, 7.0ms
# video 1/1 (96/194) /content/signs.mp4: 384x640 2 Helmets, 12.2ms
# video 1/1 (97/194) /content/signs.mp4: 384x640 (no detections), 9.7ms
# video 1/1 (98/194) /content/signs.mp4: 384x640 1 Helmet, 7.0ms
# video 1/1 (99/194) /content/signs.mp4: 384x640 1 Helmet, 7.0ms
# video 1/1 (100/194) /content/signs.mp4: 384x640 1 Helmet, 7.0ms
# video 1/1 (101/194) /content/signs.mp4: 384x640 2 Helmets, 7.0ms
# video 1/1 (102/194) /content/signs.mp4: 384x640 3 Helmets, 7.0ms
# video 1/1 (103/194) /content/signs.mp4: 384x640 2 Helmets, 8.0ms
# video 1/1 (104/194) /content/signs.mp4: 384x640 3 Helmets, 7.0ms
# video 1/1 (105/194) /content/signs.mp4: 384x640 3 Helmets, 7.0ms
# video 1/1 (106/194) /content/signs.mp4: 384x640 5 Helmets, 7.0ms
# video 1/1 (107/194) /content/signs.mp4: 384x640 3 Helmets, 7.0ms
# video 1/1 (108/194) /content/signs.mp4: 384x640 2 Helmets, 7.0ms
# video 1/1 (109/194) /content/signs.mp4: 384x640 1 Helmet, 7.0ms
# video 1/1 (110/194) /content/signs.mp4: 384x640 1 Helmet, 7.0ms
# video 1/1 (111/194) /content/signs.mp4: 384x640 2 Helmets, 7.0ms
# video 1/1 (112/194) /content/signs.mp4: 384x640 2 Helmets, 7.0ms
# video 1/1 (113/194) /content/signs.mp4: 384x640 2 Helmets, 7.0ms
# video 1/1 (114/194) /content/signs.mp4: 384x640 2 Helmets, 7.0ms
# video 1/1 (115/194) /content/signs.mp4: 384x640 2 Helmets, 7.0ms
# video 1/1 (116/194) /content/signs.mp4: 384x640 2 Helmets, 7.0ms
# video 1/1 (117/194) /content/signs.mp4: 384x640 1 Helmet, 7.0ms
# video 1/1 (118/194) /content/signs.mp4: 384x640 3 Helmets, 7.0ms
# video 1/1 (119/194) /content/signs.mp4: 384x640 (no detections), 7.0ms
# video 1/1 (120/194) /content/signs.mp4: 384x640 1 Helmet, 7.0ms
# video 1/1 (121/194) /content/signs.mp4: 384x640 1 Helmet, 7.0ms
# video 1/1 (122/194) /content/signs.mp4: 384x640 1 Helmet, 7.0ms
# video 1/1 (123/194) /content/signs.mp4: 384x640 2 Helmets, 7.0ms
# video 1/1 (124/194) /content/signs.mp4: 384x640 1 Helmet, 7.0ms
# video 1/1 (125/194) /content/signs.mp4: 384x640 2 Helmets, 7.0ms
# video 1/1 (126/194) /content/signs.mp4: 384x640 1 Helmet, 7.0ms
# video 1/1 (127/194) /content/signs.mp4: 384x640 1 Helmet, 8.0ms
# video 1/1 (128/194) /content/signs.mp4: 384x640 2 Helmets, 6.8ms
# video 1/1 (129/194) /content/signs.mp4: 384x640 2 Helmets, 6.7ms
# video 1/1 (130/194) /content/signs.mp4: 384x640 1 Helmet, 6.7ms
# video 1/1 (131/194) /content/signs.mp4: 384x640 2 Helmets, 6.7ms
# video 1/1 (132/194) /content/signs.mp4: 384x640 3 Helmets, 6.7ms
# video 1/1 (133/194) /content/signs.mp4: 384x640 3 Helmets, 6.7ms
# video 1/1 (134/194) /content/signs.mp4: 384x640 2 Helmets, 6.7ms
# video 1/1 (135/194) /content/signs.mp4: 384x640 2 Helmets, 6.8ms
# video 1/1 (136/194) /content/signs.mp4: 384x640 2 Helmets, 6.8ms
# video 1/1 (137/194) /content/signs.mp4: 384x640 3 Helmets, 6.8ms
# video 1/1 (138/194) /content/signs.mp4: 384x640 2 Helmets, 6.8ms
# video 1/1 (139/194) /content/signs.mp4: 384x640 2 Helmets, 6.7ms
# video 1/1 (140/194) /content/signs.mp4: 384x640 2 Helmets, 6.7ms
# video 1/1 (141/194) /content/signs.mp4: 384x640 3 Helmets, 6.8ms
# video 1/1 (142/194) /content/signs.mp4: 384x640 2 Helmets, 8.2ms
# video 1/1 (143/194) /content/signs.mp4: 384x640 3 Helmets, 11.2ms
# video 1/1 (144/194) /content/signs.mp4: 384x640 3 Helmets, 6.7ms
# video 1/1 (145/194) /content/signs.mp4: 384x640 3 Helmets, 6.7ms
# video 1/1 (146/194) /content/signs.mp4: 384x640 3 Helmets, 6.7ms
# video 1/1 (147/194) /content/signs.mp4: 384x640 2 Helmets, 6.8ms
# video 1/1 (148/194) /content/signs.mp4: 384x640 2 Helmets, 6.7ms
# video 1/1 (149/194) /content/signs.mp4: 384x640 4 Helmets, 11.3ms
# video 1/1 (150/194) /content/signs.mp4: 384x640 3 Helmets, 8.5ms
# video 1/1 (151/194) /content/signs.mp4: 384x640 3 Helmets, 7.6ms
# video 1/1 (152/194) /content/signs.mp4: 384x640 2 Helmets, 9.0ms
# video 1/1 (153/194) /content/signs.mp4: 384x640 3 Helmets, 8.7ms
# video 1/1 (154/194) /content/signs.mp4: 384x640 2 Helmets, 10.2ms
# video 1/1 (155/194) /content/signs.mp4: 384x640 3 Helmets, 7.2ms
# video 1/1 (156/194) /content/signs.mp4: 384x640 3 Helmets, 7.4ms
# video 1/1 (157/194) /content/signs.mp4: 384x640 3 Helmets, 7.2ms
# video 1/1 (158/194) /content/signs.mp4: 384x640 3 Helmets, 7.2ms
# video 1/1 (159/194) /content/signs.mp4: 384x640 3 Helmets, 11.3ms
# video 1/1 (160/194) /content/signs.mp4: 384x640 3 Helmets, 7.0ms
# video 1/1 (161/194) /content/signs.mp4: 384x640 1 Helmet, 7.3ms
# video 1/1 (162/194) /content/signs.mp4: 384x640 1 Helmet, 7.3ms
# video 1/1 (163/194) /content/signs.mp4: 384x640 2 Helmets, 9.9ms
# video 1/1 (164/194) /content/signs.mp4: 384x640 2 Helmets, 7.3ms
# video 1/1 (165/194) /content/signs.mp4: 384x640 3 Helmets, 7.1ms
# video 1/1 (166/194) /content/signs.mp4: 384x640 2 Helmets, 7.1ms
# video 1/1 (167/194) /content/signs.mp4: 384x640 2 Helmets, 12.1ms
# video 1/1 (168/194) /content/signs.mp4: 384x640 3 Helmets, 7.1ms
# video 1/1 (169/194) /content/signs.mp4: 384x640 2 Helmets, 7.5ms
# video 1/1 (170/194) /content/signs.mp4: 384x640 (no detections), 7.3ms
# video 1/1 (171/194) /content/signs.mp4: 384x640 (no detections), 8.1ms
# video 1/1 (172/194) /content/signs.mp4: 384x640 (no detections), 7.1ms
# video 1/1 (173/194) /content/signs.mp4: 384x640 (no detections), 7.2ms
# video 1/1 (174/194) /content/signs.mp4: 384x640 1 Helmet, 7.2ms
# video 1/1 (175/194) /content/signs.mp4: 384x640 2 Helmets, 7.3ms
# video 1/1 (176/194) /content/signs.mp4: 384x640 (no detections), 7.3ms
# video 1/1 (177/194) /content/signs.mp4: 384x640 (no detections), 7.2ms
# video 1/1 (178/194) /content/signs.mp4: 384x640 (no detections), 7.0ms
# video 1/1 (179/194) /content/signs.mp4: 384x640 (no detections), 7.3ms
# video 1/1 (180/194) /content/signs.mp4: 384x640 (no detections), 7.0ms
# video 1/1 (181/194) /content/signs.mp4: 384x640 1 Helmet, 7.0ms
# video 1/1 (182/194) /content/signs.mp4: 384x640 1 Helmet, 7.2ms
# video 1/1 (183/194) /content/signs.mp4: 384x640 1 Helmet, 10.8ms
# video 1/1 (184/194) /content/signs.mp4: 384x640 2 Helmets, 7.0ms
# video 1/1 (185/194) /content/signs.mp4: 384x640 2 Helmets, 7.6ms
# video 1/1 (186/194) /content/signs.mp4: 384x640 1 Helmet, 7.8ms
# video 1/1 (187/194) /content/signs.mp4: 384x640 2 Helmets, 6.8ms
# video 1/1 (188/194) /content/signs.mp4: 384x640 2 Helmets, 7.1ms
# video 1/1 (189/194) /content/signs.mp4: 384x640 2 Helmets, 10.4ms
# video 1/1 (190/194) /content/signs.mp4: 384x640 2 Helmets, 7.9ms
# video 1/1 (191/194) /content/signs.mp4: 384x640 2 Helmets, 8.6ms
# video 1/1 (192/194) /content/signs.mp4: 384x640 2 Helmets, 7.6ms
# video 1/1 (193/194) /content/signs.mp4: 384x640 2 Helmets, 7.6ms
# video 1/1 (194/194) /content/signs.mp4: 384x640 2 Helmets, 6.9ms
# Speed: 0.5ms pre-process, 7.6ms inference, 1.4ms NMS per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/exp

# %% [markdown]
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# <img align="left" src="https://user-images.githubusercontent.com/26833433/127574988-6a558aa1-d268-44b9-bf6b-62d4c605cc72.jpg" width="600">

# %% [markdown]
# # 2. Validate
# Validate a model's accuracy on the [COCO](https://cocodataset.org/#home) dataset's `val` or `test` splits. Models are downloaded automatically from the [latest YOLOv5 release](https://github.com/ultralytics/yolov5/releases). To show results by class use the `--verbose` flag.

# %%
# Download COCO val
torch.hub.download_url_to_file('https://ultralytics.com/assets/coco2017val.zip', 'tmp.zip')  # download (780M - 5000 images)
# !unzip -q tmp.zip -d ../datasets && rm tmp.zip  # unzip
# Out:
# 100%|██████████| 780M/780M [00:12<00:00, 66.6MB/s]

# %%
# Validate YOLOv5s on COCO val
# !python val.py --weights yolov5s.pt --data coco.yaml --img 640 --half
# Out:
# val: data=/content/yolov5/data/coco.yaml, weights=['yolov5s.pt'], batch_size=32, imgsz=640, conf_thres=0.001, iou_thres=0.6, max_det=300, task=val, device=, workers=8, single_cls=False, augment=False, verbose=False, save_txt=False, save_hybrid=False, save_conf=False, save_json=True, project=runs/val, name=exp, exist_ok=False, half=True, dnn=False
# YOLOv5 🚀 v7.0-136-g71244ae Python-3.9.16 torch-2.0.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
#
# Fusing layers...
# YOLOv5s summary: 213 layers, 7225885 parameters, 0 gradients
# val: Scanning /content/datasets/coco/val2017... 4952 images, 48 backgrounds, 0 corrupt: 100% 5000/5000 [00:02<00:00, 2024.59it/s]
# val: New cache created: /content/datasets/coco/val2017.cache
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 157/157 [01:25<00:00,  1.84it/s]
#                    all       5000      36335      0.671      0.519      0.566      0.371
# Speed: 0.1ms pre-process, 3.1ms inference, 2.3ms NMS per image at shape (32, 3, 640, 640)
#
# Evaluating pycocotools mAP... saving runs/val/exp/yolov5s_predictions.json...
# loading annotations into memory...
# Done (t=0.43s)
# creating index...
# index created!
# Loading and preparing results...
# DONE (t=5.32s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=78.89s).
# Accumulating evaluation results...
# DONE (t=14.51s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.374
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.572
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.402
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.211
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.423
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.489
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.311
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.516
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.566
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.378
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.625
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.722
# Results saved to runs/val/exp

# %% [markdown]
# # 3. Train
#
# <p align=""><a href="https://bit.ly/ultralytics_hub"><img width="1000" src="https://github.com/ultralytics/assets/raw/main/im/integrations-loop.png"/></a></p>
# Close the active learning loop by sampling images from your inference conditions with the `roboflow` pip package
# <br><br>
#
# Train a YOLOv5s model on the [COCO128](https://www.kaggle.com/ultralytics/coco128) dataset with `--data coco128.yaml`, starting from pretrained `--weights yolov5s.pt`, or from randomly initialized `--weights '' --cfg yolov5s.yaml`.
#
# - **Pretrained [Models](https://github.com/ultralytics/yolov5/tree/master/models)** are downloaded
# automatically from the [latest YOLOv5 release](https://github.com/ultralytics/yolov5/releases)
# - **[Datasets](https://github.com/ultralytics/yolov5/tree/master/data)** available for autodownload include: [COCO](https://github.com/ultralytics/yolov5/blob/master/data/coco.yaml), [COCO128](https://github.com/ultralytics/yolov5/blob/master/data/coco128.yaml), [VOC](https://github.com/ultralytics/yolov5/blob/master/data/VOC.yaml), [Argoverse](https://github.com/ultralytics/yolov5/blob/master/data/Argoverse.yaml), [VisDrone](https://github.com/ultralytics/yolov5/blob/master/data/VisDrone.yaml), [GlobalWheat](https://github.com/ultralytics/yolov5/blob/master/data/GlobalWheat2020.yaml), [xView](https://github.com/ultralytics/yolov5/blob/master/data/xView.yaml), [Objects365](https://github.com/ultralytics/yolov5/blob/master/data/Objects365.yaml), [SKU-110K](https://github.com/ultralytics/yolov5/blob/master/data/SKU-110K.yaml).
# - **Training Results** are saved to `runs/train/` with incrementing run directories, i.e. `runs/train/exp2`, `runs/train/exp3` etc.
# <br>
#
# A **Mosaic Dataloader** is used for training which combines 4 images into 1 mosaic.
#
# ## Label a dataset on Roboflow (optional)
#
# [Roboflow](https://roboflow.com/?ref=ultralytics) enables you to easily **organize, label, and prepare** a high quality dataset with your own custom data. Roboflow also makes it easy to establish an active learning pipeline, collaborate with your team on dataset improvement, and integrate directly into your model building workflow with the `roboflow` pip package.

# %%
#@title Select YOLOv5 🚀 logger {run: 'auto'}
logger = 'Comet' #@param ['Comet', 'ClearML', 'TensorBoard']

if logger == 'Comet':
  # %pip install -q comet_ml
  import comet_ml; comet_ml.init()
elif logger == 'ClearML':
  # %pip install -q clearml
  import clearml; clearml.browser_login()
elif logger == 'TensorBoard':
  # %load_ext tensorboard
  # %tensorboard --logdir runs/train

# %%
# Train YOLOv5s on COCO128 for 3 epochs
# !python train.py --img 640 --batch 16 --epochs 60 --data custom_data.yaml --weights yolov5s.pt --cache
# Out:
# train: weights=yolov5s.pt, cfg=, data=custom_data.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=60, batch_size=16, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=ram, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# YOLOv5 🚀 v7.0-169-geef637c Python-3.10.11 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
#
# hyperparameters: lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=0.05, cls=0.5, cls_pw=1.0, obj=1.0, obj_pw=1.0, iou_t=0.2, anchor_t=4.0, fl_gamma=0.0, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, mosaic=1.0, mixup=0.0, copy_paste=0.0
# ClearML: run 'pip install clearml' to automatically track, visualize and remotely train YOLOv5 🚀 in ClearML
# Comet: run 'pip install comet_ml' to automatically track and visualize YOLOv5 🚀 runs in Comet
# TensorBoard: Start with 'tensorboard --logdir runs/train', view at http://localhost:6006/
# Downloading https://github.com/ultralytics/yolov5/releases/download/v7.0/yolov5s.pt to yolov5s.pt...
# 100% 14.1M/14.1M [00:00<00:00, 136MB/s]
#
# Overriding model.yaml nc=80 with nc=1
#
#                  from  n    params  module                                  arguments
#   0                -1  1      3520  models.common.Conv                      [3, 32, 6, 2, 2]
#   1                -1  1     18560  models.common.Conv                      [32, 64, 3, 2]
#   2                -1  1     18816  models.common.C3                        [64, 64, 1]
#   3                -1  1     73984  models.common.Conv                      [64, 128, 3, 2]
#   4                -1  2    115712  models.common.C3                        [128, 128, 2]
#   5                -1  1    295424  models.common.Conv                      [128, 256, 3, 2]
#   6                -1  3    625152  models.common.C3                        [256, 256, 3]
#   7                -1  1   1180672  models.common.Conv                      [256, 512, 3, 2]
#   8                -1  1   1182720  models.common.C3                        [512, 512, 1]
#   9                -1  1    656896  models.common.SPPF                      [512, 512, 5]
#  10                -1  1    131584  models.common.Conv                      [512, 256, 1, 1]
#  11                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  12           [-1, 6]  1         0  models.common.Concat                    [1]
#  13                -1  1    361984  models.common.C3                        [512, 256, 1, False]
#  14                -1  1     33024  models.common.Conv                      [256, 128, 1, 1]
#  15                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  16           [-1, 4]  1         0  models.common.Concat                    [1]
#  17                -1  1     90880  models.common.C3                        [256, 128, 1, False]
#  18                -1  1    147712  models.common.Conv                      [128, 128, 3, 2]
#  19          [-1, 14]  1         0  models.common.Concat                    [1]
#  20                -1  1    296448  models.common.C3                        [256, 256, 1, False]
#  21                -1  1    590336  models.common.Conv                      [256, 256, 3, 2]
#  22          [-1, 10]  1         0  models.common.Concat                    [1]
#  23                -1  1   1182720  models.common.C3                        [512, 512, 1, False]
#  24      [17, 20, 23]  1     16182  models.yolo.Detect                      [1, [[10, 13, 16, 30, 33, 23], [30, 61, 62, 45, 59, 119], [116, 90, 156, 198, 373, 326]], [128, 256, 512]]
# Model summary: 214 layers, 7022326 parameters, 7022326 gradients, 15.9 GFLOPs
#
# Transferred 343/349 items from yolov5s.pt
# AMP: checks passed ✅
# optimizer: SGD(lr=0.01) with parameter groups 57 weight(decay=0.0), 60 weight(decay=0.0005), 60 bias
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01), CLAHE(p=0.01, clip_limit=(1, 4.0), tile_grid_size=(8, 8))
# train: Scanning /content/train_data/labels/train... 100 images, 0 backgrounds, 0 corrupt: 100% 100/100 [00:00<00:00, 1724.00it/s]
# train: New cache created: /content/train_data/labels/train.cache
# train: Caching images (0.1GB ram): 100% 100/100 [00:00<00:00, 541.65it/s]
# val: Scanning /content/train_data/labels/val... 599 images, 1 backgrounds, 0 corrupt: 100% 600/600 [00:00<00:00, 681.57it/s]
# val: New cache created: /content/train_data/labels/val.cache
# val: Caching images (0.5GB ram): 100% 600/600 [00:05<00:00, 103.78it/s]
#
# AutoAnchor: 5.33 anchors/target, 1.000 Best Possible Recall (BPR). Current anchors are a good fit to dataset ✅
# Plotting labels to runs/train/exp/labels.jpg...
# Image sizes 640 train, 640 val
# Using 2 dataloader workers
# Logging results to runs/train/exp
# Starting training for 60 epochs...
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#        0/59      3.46G     0.1139    0.03161          0          5        640: 100% 7/7 [00:05<00:00,  1.29it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 19/19 [00:16<00:00,  1.13it/s]
#                    all        600       1075    0.00529     0.0326    0.00205   0.000513
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#        1/59      4.83G     0.1064    0.03611          0         23        640: 100% 7/7 [00:01<00:00,  5.10it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 19/19 [00:09<00:00,  2.05it/s]
#                    all        600       1075    0.00664      0.144    0.00358   0.000849
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#        2/59      4.83G    0.08907    0.03159          0          9        640: 100% 7/7 [00:01<00:00,  5.36it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 19/19 [00:07<00:00,  2.65it/s]
#                    all        600       1075     0.0118      0.149    0.00721    0.00175
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#        3/59      4.83G    0.07916     0.0316          0         10        640: 100% 7/7 [00:01<00:00,  4.67it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 19/19 [00:07<00:00,  2.71it/s]
#                    all        600       1075     0.0161      0.475     0.0166    0.00434
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#        4/59      4.83G    0.07316    0.03222          0          6        640: 100% 7/7 [00:01<00:00,  5.22it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 19/19 [00:06<00:00,  3.10it/s]
#                    all        600       1075      0.151      0.298     0.0905      0.022
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#        5/59      4.83G    0.06819    0.03055          0          5        640: 100% 7/7 [00:01<00:00,  5.59it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 19/19 [00:05<00:00,  3.56it/s]
#                    all        600       1075      0.264      0.419      0.214     0.0526
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#        6/59      4.83G    0.07114    0.02817          0         15        640: 100% 7/7 [00:01<00:00,  5.56it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 19/19 [00:06<00:00,  3.14it/s]
#                    all        600       1075     0.0745      0.251     0.0421    0.00823
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#        7/59      4.83G    0.06903    0.02568          0          8        640: 100% 7/7 [00:01<00:00,  5.41it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 19/19 [00:05<00:00,  3.73it/s]
#                    all        600       1075      0.158      0.291      0.087     0.0168
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#        8/59      4.83G    0.06091    0.02445          0          5        640: 100% 7/7 [00:01<00:00,  4.96it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 19/19 [00:05<00:00,  3.26it/s]
#                    all        600       1075      0.145      0.349     0.0875     0.0218
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#        9/59      4.83G    0.06558    0.02533          0          5        640: 100% 7/7 [00:01<00:00,  5.68it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 19/19 [00:05<00:00,  3.80it/s]
#                    all        600       1075      0.168      0.345      0.118     0.0353
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       10/59      4.83G     0.0624    0.02587          0          9        640: 100% 7/7 [00:01<00:00,  4.15it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 19/19 [00:05<00:00,  3.51it/s]
#                    all        600       1075      0.274      0.456      0.197     0.0481
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       11/59      4.83G    0.06178    0.02519          0         11        640: 100% 7/7 [00:01<00:00,  5.17it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 19/19 [00:04<00:00,  4.01it/s]
#                    all        600       1075      0.245      0.323       0.17     0.0427
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       12/59      4.83G    0.06279    0.02232          0          8        640: 100% 7/7 [00:01<00:00,  4.73it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 19/19 [00:05<00:00,  3.74it/s]
#                    all        600       1075      0.338      0.437      0.262     0.0722
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       13/59      4.83G    0.05834    0.02054          0          4        640: 100% 7/7 [00:01<00:00,  5.56it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 19/19 [00:04<00:00,  3.83it/s]
#                    all        600       1075      0.494      0.537      0.448       0.16
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       14/59      4.83G     0.0612    0.02169          0         10        640: 100% 7/7 [00:01<00:00,  4.43it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 19/19 [00:04<00:00,  4.05it/s]
#                    all        600       1075      0.241      0.307      0.239     0.0611
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       15/59      4.83G    0.06168    0.01978          0          4        640: 100% 7/7 [00:01<00:00,  5.40it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 19/19 [00:05<00:00,  3.73it/s]
#                    all        600       1075      0.288      0.501      0.234      0.074
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       16/59      4.83G    0.05721    0.01981          0          9        640: 100% 7/7 [00:01<00:00,  4.78it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 19/19 [00:04<00:00,  4.07it/s]
#                    all        600       1075      0.432      0.505      0.453      0.174
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       17/59      4.83G    0.04897    0.01855          0          6        640: 100% 7/7 [00:01<00:00,  5.49it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 19/19 [00:05<00:00,  3.66it/s]
#                    all        600       1075      0.432      0.392      0.384       0.14
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       18/59      4.83G    0.05438    0.01903          0          8        640: 100% 7/7 [00:01<00:00,  5.21it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 19/19 [00:04<00:00,  4.11it/s]
#                    all        600       1075      0.363      0.471       0.37      0.128
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       19/59      4.83G    0.05271    0.01701          0          7        640: 100% 7/7 [00:01<00:00,  5.27it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 19/19 [00:05<00:00,  3.66it/s]
#                    all        600       1075      0.337      0.536      0.324       0.12
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       20/59      4.83G    0.04954    0.02136          0         12        640: 100% 7/7 [00:01<00:00,  5.85it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 19/19 [00:04<00:00,  4.10it/s]
#                    all        600       1075      0.531      0.474      0.483       0.17
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       21/59      4.83G    0.04759     0.0194          0          9        640: 100% 7/7 [00:01<00:00,  5.62it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 19/19 [00:05<00:00,  3.68it/s]
#                    all        600       1075      0.494      0.546      0.491      0.169
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       22/59      4.83G    0.04718    0.01689          0         10        640: 100% 7/7 [00:01<00:00,  5.54it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 19/19 [00:04<00:00,  4.15it/s]
#                    all        600       1075      0.424      0.483      0.417      0.169
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       23/59      4.83G    0.04561    0.01496          0          4        640: 100% 7/7 [00:01<00:00,  5.45it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 19/19 [00:05<00:00,  3.57it/s]
#                    all        600       1075      0.648      0.556      0.623      0.249
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       24/59      4.83G    0.04674    0.01446          0          8        640: 100% 7/7 [00:01<00:00,  5.96it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 19/19 [00:04<00:00,  4.16it/s]
#                    all        600       1075      0.425      0.545       0.43      0.123
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       25/59      4.83G    0.04283    0.01429          0          6        640: 100% 7/7 [00:01<00:00,  5.44it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 19/19 [00:05<00:00,  3.51it/s]
#                    all        600       1075      0.439       0.57      0.476       0.19
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       26/59      4.83G    0.04182    0.01519          0         11        640: 100% 7/7 [00:01<00:00,  5.77it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 19/19 [00:04<00:00,  4.15it/s]
#                    all        600       1075      0.441      0.598      0.501      0.218
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       27/59      4.83G    0.04332    0.01479          0          6        640: 100% 7/7 [00:01<00:00,  5.54it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 19/19 [00:05<00:00,  3.53it/s]
#                    all        600       1075      0.703      0.643      0.697       0.33
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       28/59      4.83G    0.04514    0.01642          0          8        640: 100% 7/7 [00:01<00:00,  5.31it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 19/19 [00:04<00:00,  4.23it/s]
#                    all        600       1075      0.696      0.621      0.639      0.218
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       29/59      4.83G    0.03811    0.01352          0          4        640: 100% 7/7 [00:01<00:00,  5.53it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 19/19 [00:05<00:00,  3.55it/s]
#                    all        600       1075      0.505      0.676      0.548      0.221
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       30/59      4.83G    0.04106    0.01465          0         12        640: 100% 7/7 [00:01<00:00,  5.51it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 19/19 [00:04<00:00,  4.19it/s]
#                    all        600       1075       0.66      0.607      0.668      0.304
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       31/59      4.83G    0.03911    0.01461          0          6        640: 100% 7/7 [00:01<00:00,  5.33it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 19/19 [00:05<00:00,  3.49it/s]
#                    all        600       1075      0.602      0.625      0.631      0.309
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       32/59      4.83G    0.04099     0.0138          0          7        640: 100% 7/7 [00:01<00:00,  5.56it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 19/19 [00:04<00:00,  4.30it/s]
#                    all        600       1075      0.733       0.66      0.662      0.242
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       33/59      4.83G    0.03846    0.01572          0         12        640: 100% 7/7 [00:01<00:00,  5.30it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 19/19 [00:05<00:00,  3.52it/s]
#                    all        600       1075      0.775       0.74      0.766      0.351
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       34/59      4.83G    0.04053    0.01562          0         13        640: 100% 7/7 [00:01<00:00,  5.15it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 19/19 [00:04<00:00,  4.19it/s]
#                    all        600       1075      0.756      0.695      0.751      0.367
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       35/59      4.83G    0.03438    0.01263          0          5        640: 100% 7/7 [00:01<00:00,  5.36it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 19/19 [00:05<00:00,  3.53it/s]
#                    all        600       1075      0.817      0.713      0.757      0.357
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       36/59      4.83G    0.03673    0.01535          0         11        640: 100% 7/7 [00:01<00:00,  5.45it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 19/19 [00:04<00:00,  4.29it/s]
#                    all        600       1075      0.764      0.683      0.694      0.255
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       37/59      4.83G     0.0363     0.0142          0          5        640: 100% 7/7 [00:01<00:00,  5.49it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 19/19 [00:05<00:00,  3.50it/s]
#                    all        600       1075      0.704      0.685      0.697      0.322
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       38/59      4.83G    0.03466     0.0144          0          8        640: 100% 7/7 [00:01<00:00,  5.46it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 19/19 [00:04<00:00,  4.21it/s]
#                    all        600       1075      0.735      0.684      0.701      0.308
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       39/59      4.83G    0.03367     0.0125          0          9        640: 100% 7/7 [00:01<00:00,  5.31it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 19/19 [00:05<00:00,  3.52it/s]
#                    all        600       1075      0.789      0.721      0.735       0.28
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       40/59      4.83G    0.03398    0.01489          0         13        640: 100% 7/7 [00:01<00:00,  5.43it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 19/19 [00:04<00:00,  4.31it/s]
#                    all        600       1075      0.785      0.715      0.719      0.282
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       41/59      4.83G    0.03207    0.01321          0          7        640: 100% 7/7 [00:01<00:00,  5.43it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 19/19 [00:05<00:00,  3.53it/s]
#                    all        600       1075      0.788      0.702      0.726      0.266
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       42/59      4.83G    0.03315    0.01211          0          6        640: 100% 7/7 [00:01<00:00,  5.41it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 19/19 [00:04<00:00,  4.20it/s]
#                    all        600       1075      0.793      0.745      0.772      0.371
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       43/59      4.83G    0.03297    0.01423          0          8        640: 100% 7/7 [00:01<00:00,  5.26it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 19/19 [00:05<00:00,  3.49it/s]
#                    all        600       1075      0.805      0.729      0.763      0.357
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       44/59      4.83G    0.03162    0.01187          0          5        640: 100% 7/7 [00:01<00:00,  5.51it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 19/19 [00:04<00:00,  4.33it/s]
#                    all        600       1075      0.739      0.726      0.705      0.264
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       45/59      4.83G    0.03096    0.01281          0         10        640: 100% 7/7 [00:01<00:00,  5.44it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 19/19 [00:05<00:00,  3.55it/s]
#                    all        600       1075      0.794      0.738      0.765       0.35
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       46/59      4.83G    0.02922    0.01171          0          7        640: 100% 7/7 [00:01<00:00,  5.40it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 19/19 [00:04<00:00,  4.29it/s]
#                    all        600       1075      0.804      0.727      0.762      0.356
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       47/59      4.83G    0.03111    0.01183          0          6        640: 100% 7/7 [00:01<00:00,  5.39it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 19/19 [00:05<00:00,  3.54it/s]
#                    all        600       1075      0.784      0.758      0.765      0.365
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       48/59      4.83G    0.03069    0.01401          0         15        640: 100% 7/7 [00:01<00:00,  5.56it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 19/19 [00:04<00:00,  4.28it/s]
#                    all        600       1075      0.769      0.727      0.732      0.288
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       49/59      4.83G    0.02982    0.01298          0         11        640: 100% 7/7 [00:01<00:00,  5.64it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 19/19 [00:05<00:00,  3.51it/s]
#                    all        600       1075      0.797       0.74      0.762      0.368
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       50/59      4.83G    0.03105     0.0117          0          8        640: 100% 7/7 [00:01<00:00,  5.47it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 19/19 [00:04<00:00,  4.27it/s]
#                    all        600       1075      0.814      0.717      0.762      0.344
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       51/59      4.83G    0.02777    0.01146          0          9        640: 100% 7/7 [00:01<00:00,  5.56it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 19/19 [00:05<00:00,  3.54it/s]
#                    all        600       1075      0.806      0.713      0.751      0.324
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       52/59      4.83G     0.0295    0.01106          0          7        640: 100% 7/7 [00:01<00:00,  5.94it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 19/19 [00:04<00:00,  4.16it/s]
#                    all        600       1075      0.812      0.714      0.764      0.347
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       53/59      4.83G    0.02691    0.01225          0          7        640: 100% 7/7 [00:01<00:00,  5.38it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 19/19 [00:05<00:00,  3.49it/s]
#                    all        600       1075      0.763      0.742      0.739      0.319
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       54/59      4.83G    0.02826    0.01246          0          6        640: 100% 7/7 [00:01<00:00,  5.19it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 19/19 [00:04<00:00,  4.25it/s]
#                    all        600       1075      0.772      0.758      0.757      0.345
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       55/59      4.83G    0.02773    0.01352          0         16        640: 100% 7/7 [00:01<00:00,  5.38it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 19/19 [00:05<00:00,  3.54it/s]
#                    all        600       1075      0.772      0.751       0.76      0.341
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       56/59      4.83G    0.02739    0.01353          0         10        640: 100% 7/7 [00:01<00:00,  5.27it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 19/19 [00:04<00:00,  4.18it/s]
#                    all        600       1075       0.76      0.744      0.738      0.309
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       57/59      4.83G    0.02614    0.01132          0          6        640: 100% 7/7 [00:01<00:00,  5.39it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 19/19 [00:05<00:00,  3.51it/s]
#                    all        600       1075      0.776      0.756      0.756      0.333
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       58/59      4.83G    0.02441    0.01079          0          4        640: 100% 7/7 [00:01<00:00,  5.30it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 19/19 [00:04<00:00,  4.28it/s]
#                    all        600       1075      0.777      0.756      0.761      0.344
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       59/59      4.83G    0.02555    0.01238          0         10        640: 100% 7/7 [00:01<00:00,  5.37it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 19/19 [00:05<00:00,  3.49it/s]
#                    all        600       1075       0.78      0.756      0.765      0.353
#
# 60 epochs completed in 0.120 hours.
# Optimizer stripped from runs/train/exp/weights/last.pt, 14.4MB
# Optimizer stripped from runs/train/exp/weights/best.pt, 14.4MB
#
# Validating runs/train/exp/weights/best.pt...
# Fusing layers...
# Model summary: 157 layers, 7012822 parameters, 0 gradients, 15.8 GFLOPs
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 19/19 [00:07<00:00,  2.43it/s]
#                    all        600       1075      0.794      0.744      0.772      0.372
# Results saved to runs/train/exp

# %% [markdown]
# # 4. Visualize

# %% [markdown]
# ## Comet Logging and Visualization 🌟 NEW
#
# [Comet](https://www.comet.com/site/lp/yolov5-with-comet/?utm_source=yolov5&utm_medium=partner&utm_campaign=partner_yolov5_2022&utm_content=yolov5_colab) is now fully integrated with YOLOv5. Track and visualize model metrics in real time, save your hyperparameters, datasets, and model checkpoints, and visualize your model predictions with [Comet Custom Panels](https://www.comet.com/docs/v2/guides/comet-dashboard/code-panels/about-panels/?utm_source=yolov5&utm_medium=partner&utm_campaign=partner_yolov5_2022&utm_content=yolov5_colab)! Comet makes sure you never lose track of your work and makes it easy to share results and collaborate across teams of all sizes!
#
# Getting started is easy:
# ```shell
# pip install comet_ml  # 1. install
# export COMET_API_KEY=<Your API Key>  # 2. paste API key
# python train.py --img 640 --epochs 3 --data coco128.yaml --weights yolov5s.pt  # 3. train
# ```
# To learn more about all of the supported Comet features for this integration, check out the [Comet Tutorial](https://docs.ultralytics.com/yolov5/tutorials/comet_logging_integration). If you'd like to learn more about Comet, head over to our [documentation](https://www.comet.com/docs/v2/?utm_source=yolov5&utm_medium=partner&utm_campaign=partner_yolov5_2022&utm_content=yolov5_colab). Get started by trying out the Comet Colab Notebook:
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/drive/1RG0WOQyxlDlo5Km8GogJpIEJlg_5lyYO?usp=sharing)
#
# <a href="https://bit.ly/yolov5-readme-comet2">
# <img alt="Comet Dashboard" src="https://user-images.githubusercontent.com/26833433/202851203-164e94e1-2238-46dd-91f8-de020e9d6b41.png" width="1280"/></a>

# %% [markdown]
# ## ClearML Logging and Automation 🌟 NEW
#
# [ClearML](https://cutt.ly/yolov5-notebook-clearml) is completely integrated into YOLOv5 to track your experimentation, manage dataset versions and even remotely execute training runs. To enable ClearML (check cells above):
#
# - `pip install clearml`
# - run `clearml-init` to connect to a ClearML server (**deploy your own [open-source server](https://github.com/allegroai/clearml-server)**, or use our [free hosted server](https://cutt.ly/yolov5-notebook-clearml))
#
# You'll get all the great expected features from an experiment manager: live updates, model upload, experiment comparison etc. but ClearML also tracks uncommitted changes and installed packages for example. Thanks to that ClearML Tasks (which is what we call experiments) are also reproducible on different machines! With only 1 extra line, we can schedule a YOLOv5 training task on a queue to be executed by any number of ClearML Agents (workers).
#
# You can use ClearML Data to version your dataset and then pass it to YOLOv5 simply using its unique ID. This will help you keep track of your data without adding extra hassle. Explore the [ClearML Tutorial](https://docs.ultralytics.com/yolov5/tutorials/clearml_logging_integration) for details!
#
# <a href="https://cutt.ly/yolov5-notebook-clearml">
# <img alt="ClearML Experiment Management UI" src="https://github.com/thepycoder/clearml_screenshots/raw/main/scalars.jpg" width="1280"/></a>

# %% [markdown]
# ## Local Logging
#
# Training results are automatically logged with [Tensorboard](https://www.tensorflow.org/tensorboard) and [CSV](https://github.com/ultralytics/yolov5/pull/4148) loggers to `runs/train`, with a new experiment directory created for each new training as `runs/train/exp2`, `runs/train/exp3`, etc.
#
# This directory contains train and val statistics, mosaics, labels, predictions and augmentated mosaics, as well as metrics and charts including precision-recall (PR) curves and confusion matrices.
#
# <img alt="Local logging results" src="https://user-images.githubusercontent.com/26833433/183222430-e1abd1b7-782c-4cde-b04d-ad52926bf818.jpg" width="1280"/>

# %% [markdown]
# # Environments
#
# YOLOv5 may be run in any of the following up-to-date verified environments (with all dependencies including [CUDA](https://developer.nvidia.com/cuda)/[CUDNN](https://developer.nvidia.com/cudnn), [Python](https://www.python.org/) and [PyTorch](https://pytorch.org/) preinstalled):
#
# - **Notebooks** with free GPU: <a href="https://bit.ly/yolov5-paperspace-notebook"><img src="https://assets.paperspace.io/img/gradient-badge.svg" alt="Run on Gradient"></a> <a href="https://colab.research.google.com/github/ultralytics/yolov5/blob/master/tutorial.ipynb"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"></a> <a href="https://www.kaggle.com/ultralytics/yolov5"><img src="https://kaggle.com/static/images/open-in-kaggle.svg" alt="Open In Kaggle"></a>
# - **Google Cloud** Deep Learning VM. See [GCP Quickstart Guide](https://docs.ultralytics.com/yolov5/environments/google_cloud_quickstart_tutorial/)
# - **Amazon** Deep Learning AMI. See [AWS Quickstart Guide](https://docs.ultralytics.com/yolov5/environments/aws_quickstart_tutorial/)
# - **Docker Image**. See [Docker Quickstart Guide](https://docs.ultralytics.com/yolov5/environments/docker_image_quickstart_tutorial/) <a href="https://hub.docker.com/r/ultralytics/yolov5"><img src="https://img.shields.io/docker/pulls/ultralytics/yolov5?logo=docker" alt="Docker Pulls"></a>

# %% [markdown]
# # Status
#
# ![YOLOv5 CI](https://github.com/ultralytics/yolov5/actions/workflows/ci-testing.yml/badge.svg)
#
# If this badge is green, all [YOLOv5 GitHub Actions](https://github.com/ultralytics/yolov5/actions) Continuous Integration (CI) tests are currently passing. CI tests verify correct operation of YOLOv5 training ([train.py](https://github.com/ultralytics/yolov5/blob/master/train.py)), testing ([val.py](https://github.com/ultralytics/yolov5/blob/master/val.py)), inference ([detect.py](https://github.com/ultralytics/yolov5/blob/master/detect.py)) and export ([export.py](https://github.com/ultralytics/yolov5/blob/master/export.py)) on macOS, Windows, and Ubuntu every 24 hours and on every commit.

# %% [markdown]
# # Appendix
#
# Additional content below.

# %%
# YOLOv5 PyTorch HUB Inference (DetectionModels only)
import torch

model = torch.hub.load('ultralytics/yolov5', 'yolov5s', force_reload=True)  # yolov5n - yolov5x6 or custom
im = 'https://ultralytics.com/images/zidane.jpg'  # file, Path, PIL.Image, OpenCV, nparray, list
results = model(im)  # inference
results.print()  # or .show(), .save(), .crop(), .pandas(), etc.
